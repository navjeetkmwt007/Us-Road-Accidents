# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
DF=pd.read_csv(r"C:\Users\narayan\Desktop\US_Accidents_Dec21_updated.csv")
DF
# Out:
#                 ID  Severity           Start_Time             End_Time  \
# 0              A-1         3  2016-02-08 00:37:08  2016-02-08 06:37:08
# 1              A-2         2  2016-02-08 05:56:20  2016-02-08 11:56:20
# 2              A-3         2  2016-02-08 06:15:39  2016-02-08 12:15:39
# 3              A-4         2  2016-02-08 06:51:45  2016-02-08 12:51:45
# 4              A-5         3  2016-02-08 07:53:43  2016-02-08 13:53:43
# ...            ...       ...                  ...                  ...
# 2845337  A-2845338         2  2019-08-23 18:03:25  2019-08-23 18:32:01
# 2845338  A-2845339         2  2019-08-23 19:11:30  2019-08-23 19:38:23
# 2845339  A-2845340         2  2019-08-23 19:00:21  2019-08-23 19:28:49
# 2845340  A-2845341         2  2019-08-23 19:00:21  2019-08-23 19:29:42
# 2845341  A-2845342         2  2019-08-23 18:52:06  2019-08-23 19:21:31
#
#          Start_Lat   Start_Lng    End_Lat     End_Lng  Distance(mi)  \
# ...

# %%
df=DF

# %%
df.head()
# Out:
#     ID  Severity           Start_Time             End_Time  Start_Lat  \
# 0  A-1         3  2016-02-08 00:37:08  2016-02-08 06:37:08  40.108910
# 1  A-2         2  2016-02-08 05:56:20  2016-02-08 11:56:20  39.865420
# 2  A-3         2  2016-02-08 06:15:39  2016-02-08 12:15:39  39.102660
# 3  A-4         2  2016-02-08 06:51:45  2016-02-08 12:51:45  41.062130
# 4  A-5         3  2016-02-08 07:53:43  2016-02-08 13:53:43  39.172393
#
#    Start_Lng    End_Lat    End_Lng  Distance(mi)  \
# 0 -83.092860  40.112060 -83.031870         3.230
# 1 -84.062800  39.865010 -84.048730         0.747
# 2 -84.524680  39.102090 -84.523960         0.055
# 3 -81.537840  41.062170 -81.535470         0.123
# 4 -84.492792  39.170476 -84.501798         0.500
#
#                                          Description  ...  Roundabout Station  \
# 0  Between Sawmill Rd/Exit 20 and OH-315/Olentang...  ...       False   False
# 1                 At OH-4/OH-235/Exit 41 - Accident.  ...       False   False
# ...

# %%
df.drop(['Roundabout','Station'	,'Stop','Traffic_Calming','Traffic_Signal','Turning_Loop'],axis=1,inplace=True)

# %%
df.drop(['Bump','Crossing',	'Give_Way','Junction','No_Exit','Railway'],axis=1,inplace=True)

# %%
nan=df.isna().sum().sort_values(ascending=False)/len(df)
x=nan.head(20)
x
# Out:
# Number                   6.129003e-01
# Precipitation(in)        1.931079e-01
# Wind_Chill(F)            1.650568e-01
# Wind_Speed(mph)          5.550967e-02
# Wind_Direction           2.592834e-02
# Humidity(%)              2.568830e-02
# Weather_Condition        2.482514e-02
# Visibility(mi)           2.479350e-02
# Temperature(F)           2.434646e-02
# Pressure(in)             2.080593e-02
# Weather_Timestamp        1.783125e-02
# Airport_Code             3.356011e-03
# Timezone                 1.285961e-03
# Sunrise_Sunset           1.007612e-03
# Civil_Twilight           1.007612e-03
# Nautical_Twilight        1.007612e-03
# Astronomical_Twilight    1.007612e-03
# Zipcode                  4.635647e-04
# City                     4.814887e-05
# Street                   7.029032e-07
# dtype: float64

# %%
df[["Number" ,"Precipitation(in)", "Wind_Chill(F)" ,"Wind_Speed(mph)"]]=df[["Number" ,"Precipitation(in)", "Wind_Chill(F)" ,"Wind_Speed(mph)"]].fillna(df[["Number" ,"Precipitation(in)", "Wind_Chill(F)" ,"Wind_Speed(mph)"]].mean())

# %%
nan=df.isna().sum().sort_values(ascending=False)/len(df)

# %%
df[["Temperature(F)" ,"Pressure(in)" ,"Weather_Timestamp" ,"Airport_Code" ,"Timezone" ,"Sunrise_Sunset" , "Civil_Twilight" ,"Nautical_Twilight" ,"Astronomical_Twilight"]]=df[["Temperature(F)" ,"Pressure(in)" ,"Weather_Timestamp" ,"Airport_Code" ,"Timezone" ,"Sunrise_Sunset" , "Civil_Twilight" ,"Nautical_Twilight" ,"Astronomical_Twilight"]].fillna(df[["Temperature(F)" ,"Pressure(in)" ,"Weather_Timestamp" ,"Airport_Code" ,"Timezone" ,"Sunrise_Sunset" , "Civil_Twilight" ,"Nautical_Twilight" ,"Astronomical_Twilight"]].mean())
# Out:
# C:\Users\narayan\AppData\Local\Temp\ipykernel_2376\1721308993.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df[["Temperature(F)" ,"Pressure(in)" ,"Weather_Timestamp" ,"Airport_Code" ,"Timezone" ,"Sunrise_Sunset" , "Civil_Twilight" ,"Nautical_Twilight" ,"Astronomical_Twilight"]]=df[["Temperature(F)" ,"Pressure(in)" ,"Weather_Timestamp" ,"Airport_Code" ,"Timezone" ,"Sunrise_Sunset" , "Civil_Twilight" ,"Nautical_Twilight" ,"Astronomical_Twilight"]].fillna(df[["Temperature(F)" ,"Pressure(in)" ,"Weather_Timestamp" ,"Airport_Code" ,"Timezone" ,"Sunrise_Sunset" , "Civil_Twilight" ,"Nautical_Twilight" ,"Astronomical_Twilight"]].mean())

# %%
df.isna().sum()
# Out:
# ID                           0
# Severity                     0
# Start_Time                   0
# End_Time                     0
# Start_Lat                    0
# Start_Lng                    0
# End_Lat                      0
# End_Lng                      0
# Distance(mi)                 0
# Description                  0
# Number                       0
# Street                       2
# Side                         0
# City                       137
# County                       0
# State                        0
# Zipcode                   1319
# Country                      0
# Timezone                  3659
# Airport_Code              9549
# Weather_Timestamp        50736
# Temperature(F)               0
# Wind_Chill(F)                0
# Humidity(%)              73092
# Pressure(in)                 0
# Visibility(mi)           70546
# Wind_Direction           73775
# Wind_Speed(mph)              0
# Precipitation(in)            0
# Weather_Condition        70636
# ...

# %%
nan=df.isna().sum().sort_values(ascending=False)/len(df)
nan
# Out:
# Wind_Direction           2.592834e-02
# Humidity(%)              2.568830e-02
# Weather_Condition        2.482514e-02
# Visibility(mi)           2.479350e-02
# Weather_Timestamp        1.783125e-02
# Airport_Code             3.356011e-03
# Timezone                 1.285961e-03
# Sunrise_Sunset           1.007612e-03
# Civil_Twilight           1.007612e-03
# Nautical_Twilight        1.007612e-03
# Astronomical_Twilight    1.007612e-03
# Zipcode                  4.635647e-04
# City                     4.814887e-05
# Street                   7.029032e-07
# Amenity                  0.000000e+00
# Precipitation(in)        0.000000e+00
# Wind_Speed(mph)          0.000000e+00
# Pressure(in)             0.000000e+00
# Wind_Chill(F)            0.000000e+00
# Temperature(F)           0.000000e+00
# ID                       0.000000e+00
# Severity                 0.000000e+00
# State                    0.000000e+00
# County                   0.000000e+00
# Side                     0.000000e+00
# ...

# %%
dd=df.describe()

# %%
dd.isna().sum()
# Out:
# Severity             0
# Start_Lat            0
# Start_Lng            0
# End_Lat              0
# End_Lng              0
# Distance(mi)         0
# Number               0
# Temperature(F)       0
# Wind_Chill(F)        0
# Humidity(%)          0
# Pressure(in)         0
# Visibility(mi)       0
# Wind_Speed(mph)      0
# Precipitation(in)    0
# dtype: int64

# %%
dd.columns
# Out:
# Index(['Severity', 'Start_Lat', 'Start_Lng', 'End_Lat', 'End_Lng',
#        'Distance(mi)', 'Number', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Speed(mph)',
#        'Precipitation(in)'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['ID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng',
#        'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'Number', 'Street',
#        'Side', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
df['Temperature(C)'] = df.apply(lambda x:x['Temperature(F)']-32,axis=1)

df['Temperature(C)'] = df.apply(lambda x:0.556*x['Temperature(C)'],axis=1)

# %%
df.drop(['Number'],axis=1,inplace=True)

# %%
df.iloc[:9,15:]
# Out:
#      Timezone Airport_Code    Weather_Timestamp  Temperature(F)  \
# 0  US/Eastern         KOSU  2016-02-08 00:53:00            42.1
# 1  US/Eastern         KFFO  2016-02-08 05:58:00            36.9
# 2  US/Eastern         KLUK  2016-02-08 05:53:00            36.0
# 3  US/Eastern         KAKR  2016-02-08 06:54:00            39.0
# 4  US/Eastern         KLUK  2016-02-08 07:53:00            37.0
# 5  US/Eastern         KI69  2016-02-08 08:16:00            35.6
# 6  US/Eastern         KFFO  2016-02-08 08:18:00            33.8
# 7  US/Eastern         KCLE  2016-02-08 11:51:00            33.1
# 8  US/Eastern         KAOH  2016-02-08 13:53:00            39.0
#
#    Wind_Chill(F)  Humidity(%)  Pressure(in)  Visibility(mi)  Wind_Speed(mph)  \
# 0      36.100000         58.0         29.76            10.0        10.400000
# 1      59.658231         91.0         29.68            10.0         7.395044
# 2      59.658231         97.0         29.70            10.0         7.395044
# ...

# %%
df[["Temperature(C)","Temperature(F)","City"]]
# Out:
#          Temperature(C)  Temperature(F)         City
# 0                5.6156            42.1       Dublin
# 1                2.7244            36.9       Dayton
# 2                2.2240            36.0   Cincinnati
# 3                3.8920            39.0        Akron
# 4                2.7800            37.0   Cincinnati
# ...                 ...             ...          ...
# 2845337         30.0240            86.0    Riverside
# 2845338         21.1280            70.0    San Diego
# 2845339         22.7960            73.0       Orange
# 2845340         21.6840            71.0  Culver City
# 2845341         26.1320            79.0     Highland
#
# [2845342 rows x 3 columns]

# %%
df["Temperature(F)"].mean()
# Out:
# 61.79355592144275

# %%
r=df["City"].value_counts().head(15)

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(14,8))
r.plot(kind="bar")
plt.show()

# %%
r2=df["Weather_Condition"].value_counts()
r3=r2.head(7)

# %%
plt.figure(figsize=(12,5))
plt.pie(x=r3.values,labels=r3.index,autopct='%.2f%%',
        explode=[0,0.1,0,0,0,0.1,0],colors=['lime','blue','m','yellow','green','aqua','red'])
plt.title('Toss Decision Percentage')
plt.show()

# %%
r6=df["Nautical_Twilight"].value_counts()

# %%
plt.figure(figsize=(12,5))
plt.pie(x=r6.values,labels=r6.index,autopct='%.2f%%',colors=['m','aqua'])
plt.title('Nautical Twilling')
plt.show()

# %%
df[df["Weather_Condition"]=="Cloudy"]["City"]
# Out:
# 25            Edinburgh
# 93           Burnsville
# 613          Gallipolis
# 815              Sutton
# 837        Summersville
#                ...
# 2845267      The Dalles
# 2845268      Clatskanie
# 2845305     Los Angeles
# 2845306       Claremont
# 2845307          Goleta
# Name: City, Length: 348767, dtype: object

# %%
df[df["Weather_Condition"]=="Overcast"]["City"]
# Out:
# 2             Cincinnati
# 3                  Akron
# 5           Williamsburg
# 8                   Lima
# 11            Cincinnati
#                ...
# 2771581         San Jose
# 2771583          Oakland
# 2785299        Brookings
# 2788029    Jordan Valley
# 2801981          Heppner
# Name: City, Length: 84882, dtype: object

# %%
df[df["Weather_Condition"]=="Mostly Cloudy"]["City"]
# Out:
# 6              Dayton
# 14           Freeport
# 15           Freeport
# 56         Louisville
# 57         Louisville
#               ...
# 2845255      Portland
# 2845265       Naselle
# 2845266       Naselle
# 2845269      Portland
# 2845273         Wasco
# Name: City, Length: 363959, dtype: object

# %%
df[df["Weather_Condition"]=="Scattered Clouds"]["City"]
# Out:
# 83                Dayton
# 100           Charleston
# 105           Cincinnati
# 121           Cincinnati
# 124             Erlanger
#                ...
# 2771672        La Puente
# 2771673        La Puente
# 2771685    National City
# 2771686      San Gabriel
# 2771701    National City
# Name: City, Length: 45132, dtype: object

# %%
df[df["Weather_Condition"]=="Fair"]["City"]
# Out:
# 746                Buffalo
# 747        Fraziers Bottom
# 2082             King City
# 3091               Cambria
# 3092               Cambria
#                 ...
# 2845336            Pacoima
# 2845337          Riverside
# 2845338          San Diego
# 2845340        Culver City
# 2845341           Highland
# Name: City, Length: 1107194, dtype: object

# %%
df[df["City"]=="Miami"]["Weather_Condition"]
# Out:
# 29519      Scattered Clouds
# 31596         Mostly Cloudy
# 31660      Scattered Clouds
# 31734              Overcast
# 31735         Mostly Cloudy
#                  ...
# 2844577       Mostly Cloudy
# 2844578                Fair
# 2844996                Fair
# 2845009              Cloudy
# 2845025                Fair
# Name: Weather_Condition, Length: 106966, dtype: object

# %%
df[["Weather_Condition","City"]].value_counts()
# Out:
# Weather_Condition   City
# Fair                Miami             39546
#                     Los Angeles       37225
# Mostly Cloudy       Miami             24395
# Fair                Orlando           22231
#                     Sacramento        18353
#                                       ...
# Light Snow          Alpine Meadows        1
#                     Alma                  1
#                     Alder Creek           1
#                     Alburgh               1
# Wintry Mix / Windy  Wood River            1
# Length: 90142, dtype: int64

# %%
df["City"].isna().sum()
# Out:
# 137

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# Weather_Condition        70636
# Visibility(mi)           70546
# Weather_Timestamp        50736
# Airport_Code              9549
# Timezone                  3659
# Sunrise_Sunset            2867
# Civil_Twilight            2867
# Nautical_Twilight         2867
# Astronomical_Twilight     2867
# Zipcode                   1319
# City                       137
# Precipitation(in)            0
# Pressure(in)                 0
# Humidity(%)                  0
# Wind_Chill(F)                0
# Temperature(F)               0
# Wind_Speed(mph)              0
# ID                           0
# Severity                     0
# Country                      0
# State                        0
# County                       0
# Description                  0
# Distance(mi)                 0
# End_Lng                      0
# End_Lat                      0
# Start_Lng                    0
# Start_Lat                    0
# End_Time                     0
# Start_Time                   0
# ...
